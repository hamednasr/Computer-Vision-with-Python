# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread('../DATA/00-puppy.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (1300, 1950, 3)

# %%
plt.imshow(img)

# %%
img_fix = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img_fix)

# %%
img_gray = cv2.imread('../DATA/00-puppy.jpg',cv2.IMREAD_GRAYSCALE)

# %%
img_gray.shape
# Out:
# (1300, 1950)

# %%
plt.imshow(img_gray,cmap='gray')

# %%
img_new = cv2.resize(img_fix,(100,80))

# %%
plt.imshow(img_new)

# %%
img_new2 = cv2.resize(img_fix,(0,0),img_fix,.5,.5)

# %%
img_new2.shape

# %%
plt.imshow(img_new2)

# %%
img_new3 = cv2.flip(img_fix,-1)

# %%
plt.imshow(img_new3)

# %%
cv2.imwrite('flipped image.jpg',img_new3)
# Out:
# True

# %%
plt.figure(figsize=(10,10))
plt.imshow(img_new3)

# %%
img_new3.shape
# Out:
# (1300, 1950, 3)
